# %% [markdown]
# # Binary Tree

# %%
from typing import Union



class BinaryTree:
    def __init__(self, node_data: str, left=None, right=None):
        self.node_data = node_data
        self.left  = left
        self.right = right

    def __str__(self):
        return str(self.node_data)

# %% [markdown]
# ## Construindo uma árvore

# %%
tree = BinaryTree("Root")
node_a = BinaryTree("Branch A")
node_b = BinaryTree("Branch B")
tree.left = node_a
tree.right = node_b

leaf_c = BinaryTree("Leaf C")
leaf_d = BinaryTree("Leaf D")
leaf_e = BinaryTree("Leaf E")
leaf_f = BinaryTree("Leaf F")
node_a.left = leaf_c
node_a.right = leaf_d
node_b.left = leaf_e
node_b.right = leaf_f

# %% [markdown]
# ## Percorrendo a árvore (traversing the Tree)

# %%
def traverse(tree: BinaryTree):
    if tree.left != None:
        traverse(tree.left)
    if tree.right != None:
        traverse(tree.right)
    print(tree.node_data)
    
traverse(tree)
# Out:
# Leaf C
# Leaf D
# Branch A
# Leaf E
# Leaf F
# Branch B
# Root

# %% [markdown]
# Como mostra o resultado, a função traverse não imprime nada até chegar na primeira folha. Então, ela imprime ambas as folhas e o pai dessas folhas. A travessia segue o galho esquerdo primeiro, e depois o galho direito. O nó raiz vem por último.

# %% [markdown]
# Há diferentes tipos de estruturas de armazenamento de dados. Aqui está uma lista rápida dos tipos comumente encontrados:
#
# **Árvores balanceadas**: É um tipo de árvore que mantém uma estrutura balanceada através de uma reorganização que permita tempos de acesso reduzidos. O número de elementos do lado direito difere do número do lado esquerdo em, no máximo, um.
#
# **Árvores não balanceadas**: Esta é uma árvore que coloca novos itens de dados onde for necessário em uma árvore, sem se importar com o balanço. Esse método de adicionar itens torna mais rápida a construção da árvore, mas reduz a velocidade de acesso em buscas e ordenamentos.
#
# **Heaps**: Uma árvore balanceada sofisticada, que permite a inserção de dados em sua estrutura. O uso da inserção de dados torna o ordenamento mais rápido. Você pode, depois, classificar essas árvores em max heaps (todos os nós são menores que seus respectivos pais) e min heaps (todos os nós são maiores que seus respectivos pais), dependendo da sua capacidade de fornecer imediatamente o valor máximo ou mínimo nela presente.
